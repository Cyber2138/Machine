# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('house prices.csv')
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
x = df.Area 
y = df.Price 

plt.scatter(x,y)
plt.title('House price prediction')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %%
from scipy import stats
def regress(n):
    return slope * n + intercepts

slope, intercepts, r,p, stand_err= stats.linregress(x,y)

model = list(map(regress, x))

plt.scatter(x,y)
plt.plot(x, model)
plt.show()

# %%
value = regress(5000)
value
# Out:
# 859554.7945205478

# %%
from sklearn.linear_model import LinearRegression
categorical_features = df.drop("Price", axis=1)
target = df.Price
lr = LinearRegression()
lr.fit(categorical_features,target)
lr.score(categorical_features,target)
# Out:
# 0.9584301138199486

# %%
import pickle
with open('model prediction','wb') as f:
    pickle.dump(lr, f)

# %%
with open("model prediction", 'rb') as f:
    model = pickle.load(f)
    print(model.predict([[2000]]))
# Out:
# [452191.78082192]
